# %%
import numpy as np
import pandas as pd

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      ---- ----------------------------------- 20.5/165.5 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.5 kB 325.1 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/165.5 kB 325.1 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/165.5 kB 325.1 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/165.5 kB 163.4 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/165.5 kB 163.4 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/165.5 kB 163.4 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/165.5 kB 156.1 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/165.5 kB 156.1 kB/s eta 0:00:01
#      ---------------- -------------------- 71.7/165.5 kB 145.6 kB/s eta 0:00:01
# ...

# %% [markdown]
# ### Building Vocabulary

# %%
from collections import Counter
vocab = Counter()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 vocab.update(data["tweet"])
#
# NameError: name 'data' is not defined

# %%
vocab
# Out:
# Counter()

# %%
data["tweet"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data["tweet"]
#
# NameError: name 'data' is not defined
